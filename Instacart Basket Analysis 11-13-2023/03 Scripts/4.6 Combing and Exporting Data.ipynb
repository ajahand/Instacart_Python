# %% [markdown]
# # 4.6: Combining & Exporting Data

# %% [markdown]
# 3. In a new notebook, import the orders_products_combined dataframe from the pickle file you just saved.
#
# 4. Check the shape of the imported dataframe (it should be the same as the one you exported—always check!).
#
# 5.Determine a suitable way to combine the orders_products_combined dataframe with your products data set. Make sure you’re using your wrangled, cleaned, and deduped products data set stored in your “Prepared Data” folder from the previous Exercise’s task.
#
# 6. Confirm the results of the merge using the merge flag.

# %%
# importing libraries 
import pandas as pd
import numpy as np
import os

# %%
#import data
path = r'/Users/ajahanderson/Documents/Instacart Basket Analysis 11-13-2023'

# %%
df = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data','orders_products_combined.pkl'))

# %%
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data','products_checked.csv'))

# %% [markdown]
# ## 4. Checking the data frames

# %%
#checking shape 
df_prods.shape
# Out:
# (49693, 6)

# %%
df.shape
# Out:
# (32434489, 12)

# %%
df_prods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49693 entries, 0 to 49692
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     49693 non-null  int64
#  1   product_id     49693 non-null  int64
#  2   product_name   49677 non-null  object
#  3   aisle_id       49693 non-null  int64
#  4   department_id  49693 non-null  int64
#  5   prices         49693 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 2.3+ MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32434489 entries, 0 to 32434488
# Data columns (total 12 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   Unnamed: 0                int64
#  1   order_id                  int64
#  2   user_id                   int64
#  3   order_number              int64
#  4   day_of_week_order_placed  int64
#  5   order_time                int64
#  6   days_since_prior_order    float64
#  7   ('user_id',)              int64
#  8   product_id                int64
#  9   add_to_cart_order         int64
#  10  reordered                 int64
#  11  _merge                    category
# dtypes: category(1), float64(1), int64(10)
# memory usage: 2.7 GB

# %%
df.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  day_of_week_order_placed  \
# 0           0   2539329        1             1                         2
# 1           0   2539329        1             1                         2
# 2           0   2539329        1             1                         2
# 3           0   2539329        1             1                         2
# 4           0   2539329        1             1                         2
#
#    order_time  days_since_prior_order  ('user_id',)  product_id  \
# 0           8                     NaN             1         196
# 1           8                     NaN             1       14084
# 2           8                     NaN             1       12427
# 3           8                     NaN             1       26088
# 4           8                     NaN             1       26405
#
#    add_to_cart_order  reordered _merge
# 0                  1          0   both
# 1                  2          0   both
# ...

# %%
df.drop(columns = ['user_id'])
# Out:
#           Unnamed: 0  order_id  order_number  day_of_week_order_placed  \
# 0                  0   2539329             1                         2
# 1                  0   2539329             1                         2
# 2                  0   2539329             1                         2
# 3                  0   2539329             1                         2
# 4                  0   2539329             1                         2
# ...              ...       ...           ...                       ...
# 32434484     3421081   2977660            13                         1
# 32434485     3421081   2977660            13                         1
# 32434486     3421081   2977660            13                         1
# 32434487     3421081   2977660            13                         1
# 32434488     3421081   2977660            13                         1
#
#           order_time  days_since_prior_order  ('user_id',)  product_id  \
# ...

# %%
df.rename(columns = {'''user_id,''' : 'user_id'}, inplace = True)
# i tried to delete that extra ('user_id',) but it wouldn't pull up so i tried to delete the original and rename and they're both still popping up

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32434489 entries, 0 to 32434488
# Data columns (total 12 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   Unnamed: 0                int64
#  1   order_id                  int64
#  2   user_id                   int64
#  3   order_number              int64
#  4   day_of_week_order_placed  int64
#  5   order_time                int64
#  6   days_since_prior_order    float64
#  7   ('user_id',)              int64
#  8   product_id                int64
#  9   add_to_cart_order         int64
#  10  reordered                 int64
#  11  _merge                    category
# dtypes: category(1), float64(1), int64(10)
# memory usage: 2.7 GB

# %%
df_prods = df_prods.drop(columns = ['Unnamed: 0'])

# %%
df = df.drop(columns = [ 'Unnamed: 0', '_merge'])

# %%
#double checking that it dropped
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
df.head()
# Out:
#    order_id  user_id  order_number  day_of_week_order_placed  order_time  \
# 0   2539329        1             1                         2           8
# 1   2539329        1             1                         2           8
# 2   2539329        1             1                         2           8
# 3   2539329        1             1                         2           8
# 4   2539329        1             1                         2           8
#
#    days_since_prior_order  ('user_id',)  product_id  add_to_cart_order  \
# 0                     NaN             1         196                  1
# 1                     NaN             1       14084                  2
# 2                     NaN             1       12427                  3
# 3                     NaN             1       26088                  4
# 4                     NaN             1       26405                  5
#
#    reordered
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %% [markdown]
# # 5. Merging the columns

# %%
#merging columns
df_merged = df_prods.merge(df, on = 'product_id', indicator = True)

# %%
df_merged
# Out:
#           product_id                product_name  aisle_id  department_id  \
# 0                  1  Chocolate Sandwich Cookies        61             19
# 1                  1  Chocolate Sandwich Cookies        61             19
# 2                  1  Chocolate Sandwich Cookies        61             19
# 3                  1  Chocolate Sandwich Cookies        61             19
# 4                  1  Chocolate Sandwich Cookies        61             19
# ...              ...                         ...       ...            ...
# 32434207       49688      Fresh Foaming Cleanser        73             11
# 32434208       49688      Fresh Foaming Cleanser        73             11
# 32434209       49688      Fresh Foaming Cleanser        73             11
# 32434210       49688      Fresh Foaming Cleanser        73             11
# 32434211       49688      Fresh Foaming Cleanser        73             11
#
#           prices  order_id  user_id  order_number  day_of_week_order_placed  \
# ...

# %% [markdown]
# # 6. Comfirming Merge

# %%
df_merged['_merge'].value_counts()
# Out:
# _merge
# both          32434212
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
#Export orders_products_merged file
df_merged.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
df_merged.columns[11]
# Out:
# "('user_id',)"

# %%
df_merged.drop(df_merged.columns[11], axis=1, inplace=True)

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32434212 entries, 0 to 32434211
# Data columns (total 14 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   product_id                int64
#  1   product_name              object
#  2   aisle_id                  int64
#  3   department_id             int64
#  4   prices                    float64
#  5   order_id                  int64
#  6   user_id                   int64
#  7   order_number              int64
#  8   day_of_week_order_placed  int64
#  9   order_time                int64
#  10  days_since_prior_order    float64
#  11  add_to_cart_order         int64
#  12  reordered                 int64
#  13  _merge                    category
# dtypes: category(1), float64(2), int64(10), object(1)
# memory usage: 3.2+ GB

# %%
#Export orders_products_merged file
df_merged.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
df_merged['day_of_week_order_placed'] = df_merged['day_of_week_order_placed'].astype('int')

# %%
df_merged['order_time'] = df_merged['order_time'].astype('int')

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32434212 entries, 0 to 32434211
# Data columns (total 14 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   product_id                int64
#  1   product_name              object
#  2   aisle_id                  int64
#  3   department_id             int64
#  4   prices                    float64
#  5   order_id                  int64
#  6   user_id                   int64
#  7   order_number              int64
#  8   day_of_week_order_placed  int64
#  9   order_time                int64
#  10  days_since_prior_order    float64
#  11  add_to_cart_order         int64
#  12  reordered                 int64
#  13  _merge                    category
# dtypes: category(1), float64(2), int64(10), object(1)
# memory usage: 3.2+ GB

# %%
#Export orders_products_merged file
df_merged.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))
